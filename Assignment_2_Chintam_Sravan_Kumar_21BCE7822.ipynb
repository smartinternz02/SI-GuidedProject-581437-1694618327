# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Name: **CHINTAM SRAVAN KUMAR** <br>
# Registration Number: **21BCE7822** <br>
# Branch: **Computer Science and Engineering with Specialization Data Analytics** <br>
# Mail ID: **sravan.21bce7822@vitapstudent.ac.in** <br>
# Evening Batch :**6pm-8pm**<br>
# Campus: **VIT-AP** <br>
# Course: **Artificial Intelligence and Machine Learning**<br>

# %% [markdown]
# **Download and Loading**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("House Price India.csv")

# %% [markdown]
# **Performing the Below Visualizations.**

# %% [markdown]
# **Univariate Analysis**

# %%
a=df["Distance from the airport"]
sns.boxplot(a)
# Out:
# <Axes: >

# %%
a=df["lot area"]
plt.pie(a)
plt.show()

# %% [markdown]
# **Bivariate Analysis**

# %%
b=df["Number of schools nearby"]
c=df["condition of the house"]
plt.plot(b,c)
plt.show()

# %%
d=df["number of bedrooms"]
e=df["number of bathrooms"]
plt.scatter(d,e)
plt.show()

# %% [markdown]
# **Multivariate Analysis**

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Perform descriptive statistics on the dataset.**

# %%
print(df.describe())
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# **Handle the Missing values.**

# %%
print(df.isnull().any())
print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(df.isnull().sum())
#There is no missing values
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...
